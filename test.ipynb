# %%
import os

file_path = os.getcwd() + '/test.csv'
with open(file_path, 'w') as f:
    f.write('Hello, world!\n')

with open(file_path, 'r') as f:
    print(f.readline().strip())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[7], line 4
#       1 import os
#       3 with open(os.getcwd() + '/data/text2text.csv', 'w') as f:
# ----> 4     print(f.readline().strip())
#
# UnsupportedOperation: not readable

# %%
print('You are a data annotator preparing training examples for fine-tuning a Text-to-Text generation model (like FLAN-T5). \n\nGiven the following raw case study or technical description, extract ONLY factual input/output pairs suitable for supervised learning. Focus on tasks like summarisation, question answering, classification, or instruction following — all expressed in text-to-text format. \n\nReturn up to 5 examples in this format: \n\n<input> => <output> \n\nHere is the text: \"\"\"')
# Out:
# You are a data annotator preparing training examples for fine-tuning a Text-to-Text generation model (like FLAN-T5).
#
# Given the following raw case study or technical description, extract ONLY factual input/output pairs suitable for supervised learning. Focus on tasks like summarisation, question answering, classification, or instruction following — all expressed in text-to-text format.
#
# Return up to 5 examples in this format:
#
# <input> => <output>
#
# Here is the text: """
